# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sentences = [
    "Sun is bright.",
    "Coffee is hot coffee.",
    "Dog runs very fast.",
    "Rain falls and falls.",
    "Music is loud music.",
    "Stars shine at night.",
    "He runs and runs.",
    "She smiles and smiles."
]

# %%
sentences
# Out:
# ['Sun is bright.',
#  'Coffee is hot coffee.',
#  'Dog runs very fast.',
#  'Rain falls and falls.',
#  'Music is loud music.',
#  'Stars shine at night.',
#  'He runs and runs.',
#  'She smiles and smiles.']

# %%
#### vocabulary size

vocab_size=10000

# %%
#### applying one hot encoding


one_hot_repr=[one_hot(words,vocab_size) for words in sentences]
one_hot_repr
# Out:
# [[6977, 5573, 944],
#  [8595, 5573, 4794, 8595],
#  [6212, 2039, 1230, 3508],
#  [9798, 2502, 8909, 2502],
#  [5841, 5573, 1473, 5841],
#  [4546, 8939, 3979, 8283],
#  [2252, 2039, 8909, 2039],
#  [7868, 2925, 8909, 2925]]

# %%
### word embedding representation

from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=6
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0 6977 5573  944]
#  [   0    0 8595 5573 4794 8595]
#  [   0    0 6212 2039 1230 3508]
#  [   0    0 9798 2502 8909 2502]
#  [   0    0 5841 5573 1473 5841]
#  [   0    0 4546 8939 3979 8283]
#  [   0    0 2252 2039 8909 2039]
#  [   0    0 7868 2925 8909 2925]]

# %%
#### feature representation

dim=10

# %%
model=Sequential()
model.add(Embedding(vocab_size,dim,input_length=sent_length))
model.compile('adam','mse')

# %%
# build model so Embedding weights are created
model.build((None, sent_length))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 6, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# array([[[ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [-0.04646481, -0.03793439, -0.03002741, -0.01806056,
#           0.01422871, -0.03004833,  0.02099613, -0.02569382,
#          -0.04084489,  0.04586797],
#         [-0.0069498 , -0.01691566, -0.03503663,  0.02285895,
#          -0.04970759, -0.02673147, -0.01429   ,  0.01898748,
#           0.03769578, -0.02544506],
#         [ 0.04368978, -0.02555447, -0.00582609, -0.0080317 ,
#          -0.0305723 ,  0.03215773, -0.00916536,  0.00247393,
#           0.03527625, -0.01525604]],
#
#        [[ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [-0.02975783, -0.01289346,  0.01808936, -0.00829304,
#           0.03224831,  0.00295484,  0.00417049,  0.02044114,
#          -0.03766254,  0.01010591],
#         [-0.0069498 , -0.01691566, -0.03503663,  0.02285895,
#          -0.04970759, -0.02673147, -0.01429   ,  0.01898748,
#           0.03769578, -0.02544506],
#         [ 0.00827938,  0.03236431, -0.03895243,  0.01249852,
#          -0.01238586, -0.04832747, -0.0407127 ,  0.02789298,
#          -0.00354205,  0.01985412],
#         [-0.02975783, -0.01289346,  0.01808936, -0.00829304,
#           0.03224831,  0.00295484,  0.00417049,  0.02044114,
#          -0.03766254,  0.01010591]],
#
#        [[ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [ 0.01798297,  0.01709146,  0.02939748,  0.00916809,
#          -0.02230759, -0.00463606,  0.00771209, -0.01064746,
#          -0.04788799,  0.03456655],
#         [ 0.0176389 ,  0.04569897, -0.00870446, -0.0301062 ,
#          -0.03643852,  0.00515991,  0.04493227,  0.00310697,
#          -0.0185158 , -0.0404961 ],
#         [ 0.00951314, -0.02341137, -0.04844599, -0.01670208,
#          -0.04387133, -0.01039276,  0.01768808,  0.00681908,
#          -0.04419784, -0.00783193],
#         [ 0.02123452,  0.04268446, -0.02210046, -0.03011307,
#           0.03152553,  0.04305276,  0.01608359,  0.03018118,
#           0.00285616,  0.03467805]],
#
#        [[ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [ 0.0286249 , -0.04106801, -0.0069499 ,  0.03828088,
#           0.04931271,  0.04020317, -0.01558691,  0.04059598,
#          -0.03204598,  0.03645873],
#         [-0.01791426, -0.02876214,  0.04426242,  0.00328412,
#          -0.02778194,  0.03932827,  0.01741046,  0.01704948,
#          -0.02130841,  0.02777949],
#         [-0.02956944, -0.04658847, -0.02213997,  0.03421939,
#          -0.02895935,  0.01189256,  0.02914811, -0.01584839,
#           0.04699352, -0.0275335 ],
#         [-0.01791426, -0.02876214,  0.04426242,  0.00328412,
#          -0.02778194,  0.03932827,  0.01741046,  0.01704948,
#          -0.02130841,  0.02777949]],
#
#        [[ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [-0.04916538,  0.02359423,  0.04593351,  0.00568261,
#           0.03865876, -0.00688163,  0.00378209,  0.04196118,
#           0.02604202,  0.01832424],
#         [-0.0069498 , -0.01691566, -0.03503663,  0.02285895,
#          -0.04970759, -0.02673147, -0.01429   ,  0.01898748,
#           0.03769578, -0.02544506],
#         [ 0.01736308,  0.03073504,  0.00577063, -0.02556211,
#          -0.03194707,  0.02294556,  0.04425338, -0.02576648,
#          -0.02401973, -0.03108269],
#         [-0.04916538,  0.02359423,  0.04593351,  0.00568261,
#           0.03865876, -0.00688163,  0.00378209,  0.04196118,
#           0.02604202,  0.01832424]],
#
#        [[ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [-0.0146751 , -0.0056139 ,  0.02460222, -0.0023625 ,
#           0.04176794, -0.04006058,  0.02345135,  0.04009216,
#          -0.01030077,  0.03969311],
#         [-0.04309407, -0.00292305,  0.0341997 , -0.00048342,
#          -0.03316548,  0.03868974,  0.04277888, -0.03957438,
#           0.02770991,  0.00464487],
#         [ 0.03892921,  0.01475717, -0.0372364 ,  0.00214499,
#          -0.03876178,  0.0255633 , -0.02298707, -0.04595141,
#          -0.02815328, -0.04933468],
#         [ 0.00782509,  0.01094395, -0.00159412, -0.00806122,
#           0.03182432,  0.02784685,  0.03104879,  0.02566575,
#          -0.00035238,  0.03153528]],
#
#        [[ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [-0.04792426, -0.03690107,  0.04572568, -0.0153309 ,
#          -0.04714065, -0.04680034,  0.01143225, -0.00139032,
#          -0.02709737,  0.00239463],
#         [ 0.0176389 ,  0.04569897, -0.00870446, -0.0301062 ,
#          -0.03643852,  0.00515991,  0.04493227,  0.00310697,
#          -0.0185158 , -0.0404961 ],
#         [-0.02956944, -0.04658847, -0.02213997,  0.03421939,
#          -0.02895935,  0.01189256,  0.02914811, -0.01584839,
#           0.04699352, -0.0275335 ],
#         [ 0.0176389 ,  0.04569897, -0.00870446, -0.0301062 ,
#          -0.03643852,  0.00515991,  0.04493227,  0.00310697,
#          -0.0185158 , -0.0404961 ]],
#
#        [[ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [ 0.03610073, -0.01280812,  0.04175503,  0.02207717,
#          -0.00661715,  0.02259948, -0.04390264,  0.03590362,
#          -0.02348472,  0.00668705],
#         [ 0.03640581,  0.03157295, -0.0177098 ,  0.0137285 ,
#          -0.02724048, -0.02500917,  0.03184367,  0.04747465,
#          -0.02699585,  0.00803894],
#         [-0.02956944, -0.04658847, -0.02213997,  0.03421939,
#          -0.02895935,  0.01189256,  0.02914811, -0.01584839,
#           0.04699352, -0.0275335 ],
#         [ 0.03640581,  0.03157295, -0.0177098 ,  0.0137285 ,
#          -0.02724048, -0.02500917,  0.03184367,  0.04747465,
#          -0.02699585,  0.00803894]]], dtype=float32)

# %%
# pass a batched sample (shape: 1 x sent_length) to avoid shape errors
model.predict(np.expand_dims(embedded_docs[0], 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# array([[[ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [ 0.03069583,  0.03247822,  0.00212836, -0.04853854,
#          -0.03476848,  0.00866593, -0.00979584, -0.025225  ,
#           0.03414248, -0.00230453],
#         [-0.04646481, -0.03793439, -0.03002741, -0.01806056,
#           0.01422871, -0.03004833,  0.02099613, -0.02569382,
#          -0.04084489,  0.04586797],
#         [-0.0069498 , -0.01691566, -0.03503663,  0.02285895,
#          -0.04970759, -0.02673147, -0.01429   ,  0.01898748,
#           0.03769578, -0.02544506],
#         [ 0.04368978, -0.02555447, -0.00582609, -0.0080317 ,
#          -0.0305723 ,  0.03215773, -0.00916536,  0.00247393,
#           0.03527625, -0.01525604]]], dtype=float32)
